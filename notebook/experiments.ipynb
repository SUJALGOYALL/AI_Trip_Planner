# %%
print("ok")
# Out:
# ok

# %%
from dotenv import load_dotenv

# %%
from langchain_groq import ChatGroq

# %%
llm = ChatGroq(model="openai/gpt-oss-120b")

# %%
llm.invoke("What is the capital of France?")
# Out:
# AIMessage(content='The capital of France is **Paris**.', additional_kwargs={'reasoning_content': 'The user asks a simple factual question: "What is the capital of France?" The answer is "Paris". Provide concise answer.'}, response_metadata={'token_usage': {'completion_tokens': 45, 'prompt_tokens': 78, 'total_tokens': 123, 'completion_time': 0.096333819, 'completion_tokens_details': {'reasoning_tokens': 27}, 'prompt_time': 0.003164552, 'prompt_tokens_details': None, 'queue_time': 0.046469494, 'total_time': 0.099498371}, 'model_name': 'openai/gpt-oss-120b', 'system_fingerprint': 'fp_8a618bed98', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019c3292-7ab8-7061-a8c1-43648a1a66b5-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 78, 'output_tokens': 45, 'total_tokens': 123, 'output_token_details': {'reasoning': 27}})

# %%
from langchain.tools import tool

# %%
@tool
def multiply(a: int, b: int) -> int:
    """Multiplies two numbers."""
    return a * b

# %%
multiply
# Out:
# StructuredTool(name='multiply', description='Multiplies two numbers.', args_schema=<class 'langchain_core.utils.pydantic.multiply'>, func=<function multiply at 0x000001DBB0A6E8E0>)

# %%
from langchain_core.tools import StructuredTool

# %%
from pydantic import BaseModel

# %%
class WeatherInput(BaseModel):
    city: str

# %%
def get_weather(city: str) -> str:
    """Returns the current weather in a given city."""
    # In a real implementation, this would call a weather API.
    return f"The current weather in {city} is sunny with a high of 25°C."

# %%
weather_tool = StructuredTool.from_function(
    func = get_weather,
    name = "get_weather",
    description="Get the current weather in a given city.",
    args_schema=WeatherInput
)
